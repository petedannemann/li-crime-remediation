# %%
# %matplotlib inline

import geopandas as gpd
import fiona

# %% [markdown]
# Read in Data

# %%
remediations = gpd.read_file('../data/remediations_poly.shp')

# %%
remediations.plot()

# %% [markdown]
# Buffer the remediations by 1/4 mile

# %%
remediations['geometry'] = remediations['geometry'].buffer(distance=1320)

# %%
remediations.plot()

# %%
remediations.to_file('../data/remediations_buffer.shp')
